# %% [markdown]
# # Load and plot image
#
# This starter notebook does three things: load a file, get image data, and plot it with Matplotlib. Matplotlib is used only in documentation/notebook examples, not in the CloudScope runtime dependencies.

# %%
from pathlib import Path

import matplotlib.pyplot as plt

from acqstore.sample_data import ensure_sample
from acqstore.acq_image.acq_image_list import AcqImageList, PathKind

# %% [markdown]
# ## Load sample data
#
# Use `cloudscope-data` sample data for a reproducible first run. Replace this with a local `.oir`, `.czi`, `.tif`, or `.ome.zarr` path when adapting the notebook.

# %%
sample_folder = ensure_sample("demo-small")
acq_list = AcqImageList(str(sample_folder), path_kind=PathKind.FOLDER)

acq = acq_list.get_files()[0]
print(acq.name)
# Out:
# did not understand "radon_velocity" available analysis names are []
# Failed to load sidecar JSON for /Users/cudmore/Library/Application Support/cloudscope/sample-data/demo-small-v1/demo-small/cond1/20251030_A106_0002.oir: "No analysis class registered for 'radon_velocity'"
# did not understand "radon_velocity" available analysis names are []
# Failed to load sidecar JSON for /Users/cudmore/Library/Application Support/cloudscope/sample-data/demo-small-v1/demo-small/cond2/20251030_A106_0003.oir: "No analysis class registered for 'radon_velocity'"
# did not understand "radon_velocity" available analysis names are []
# Failed to load sidecar JSON for /Users/cudmore/Library/Application Support/cloudscope/sample-data/demo-small-v1/demo-small/cond2/20251030_A106_0004.oir: "No analysis class registered for 'radon_velocity'"
# did not understand "radon_velocity" available analysis names are []
# Failed to load sidecar JSON for /Users/cudmore/Library/Application Support/cloudscope/sample-data/demo-small-v1/demo-small/cond2/20251030_A106_0005.oir: "No analysis class registered for 'radon_velocity'"
# 20251030_A106_0002.oir

# %% [markdown]
# ## Get image data
#
# This example asks the file loader for a single 2D plane. Exact loader APIs may evolve; the intent is to keep notebook examples close to the public `acqstore` scripting interface.

# %%
channel = acq.get_default_channel() or 0
image = acq.images.get_slice_data(channel=channel, z=0, t=0)
print(image.shape, image.dtype)
# Out:
# (30000, 24) uint16

# %% [markdown]
# ## Plot with Matplotlib

# %%
plt.figure(figsize=(8, 5))
plt.imshow(image, cmap="gray")
plt.title(f"{acq.name} — channel {channel}")
plt.axis("off");
