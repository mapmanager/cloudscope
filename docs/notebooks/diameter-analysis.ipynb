# %% [markdown]
# # Diameter analysis
#
# Starter notebook for diameter analysis. This phase-1 notebook is rendered in the documentation but is not executed in CI.

# %%
from acqstore.sample_data import ensure_sample
from acqstore.acq_image.acq_image_list import AcqImageList, PathKind

sample_folder = ensure_sample("demo-small")
acq_list = AcqImageList(str(sample_folder), path_kind=PathKind.FOLDER)
acq = acq_list.get_files()[0]
print(acq.name)

# %% [markdown]
# ## Next steps
#
# This notebook will be expanded after the API-docstring pass to show the preferred public scripting API for selecting an ROI, running diameter analysis, and reading result tables.

# %%
# TODO: select channel/ROI, configure diameter parameters, run analysis, inspect results.
